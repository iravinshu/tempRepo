# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(101)
scores = np.random.randint(0,101, (4,3)) # 4 player 3 match
print(scores)
# Out:
# [[95 11 81]
#  [70 63 87]
#  [75  9 77]
#  [40  4 63]]

# %%
players = ['Virat', 'MS Dhoni', 'KL Rahul', 'Rohit']
matches = ['Match 1', 'Match 2', 'Match 3']

# %%
df = pd.DataFrame(data=scores)

# %%
df
# Out:
#     0   1   2
# 0  95  11  81
# 1  70  63  87
# 2  75   9  77
# 3  40   4  63

# %%
df = pd.DataFrame(data=scores)
df
# Out:
#     0   1   2
# 0  95  11  81
# 1  70  63  87
# 2  75   9  77
# 3  40   4  63

# %%
df = pd.DataFrame(data=scores, index=players, columns=matches)
df
# Out:
#           Match 1  Match 2  Match 3
# Virat          95       11       81
# MS Dhoni       70       63       87
# KL Rahul       75        9       77
# Rohit          40        4       63

# %%
df.loc['Virat']
# Out:
# Match 1    95
# Match 2    11
# Match 3    81
# Name: Virat, dtype: int32

# %%
df.loc[['Virat', 'Rohit']]
# Out:
#        Match 1  Match 2  Match 3
# Virat       95       11       81
# Rohit       40        4       63

# %%
print(df.loc['Virat', 'Match 2'])
# Out:
# 11
