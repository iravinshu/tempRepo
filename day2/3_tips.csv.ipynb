# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tips.csv')

# %%
print(df.columns)
print(df.index)
print(df.head())
print(df.tail())
print(df.info())
# Out:
# Index(['total_bill', 'tip', 'gender', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')
# RangeIndex(start=0, stop=244, step=1)
#    total_bill  tip  gender smoker  day    time  size  price_per_person  \
# 0          17    1  Female     No  Sun  Dinner     2                 8
# 1          10    2    Male     No  Sun  Dinner     3                 3
# 2          21    4    Male     No  Sun  Dinner     3                 7
# 3          24    3    Male     No  Sun  Dinner     2                12
# 4          25    4  Female     No  Sun  Dinner     4                 6
#
#            Payer Name        CC Number Payment ID
# 0  Christy Cunningham 3560330000000000    Sun2959
# 1      Douglas Tucker 4478070000000000    Sun4608
# 2      Travis Walters 6011810000000000    Sun4458
# 3    Nathaniel Harris 4676140000000000    Sun5260
# 4        Tonya Carter 4832730000000000    Sun2251
# ...

# %%
print(len(df))
print(df.describe())
# Out:
# 244
#        total_bill  tip  size  price_per_person        CC Number
# count         244  244   244               244              244
# mean           20    3     3                 8 2563495461217592
# std             9    1     1                 3 2369339716610890
# min             3    1     1                 3      60406789937
# 25%            13    2     2                 6   30407325000000
# 50%            18    3     2                 7 3525320000000000
# 75%            24    4     3                 9 4553675000000000
# max            51   10     6                20 6596450000000000

# %%
print(df.describe().transpose())
# Out:
#                   count             mean              std         min  \
# total_bill          244               20                9           3
# tip                 244                3                1           1
# size                244                3                1           1
# price_per_person    244                8                3           3
# CC Number           244 2563495461217592 2369339716610890 60406789937
#
#                             25%              50%              75%  \
# total_bill                   13               18               24
# tip                           2                3                4
# size                          2                2                3
# price_per_person              6                7                9
# CC Number        30407325000000 3525320000000000 4553675000000000
#
#                               max
# total_bill                     51
# tip                            10
# size                            6
# ...

# %%
pd.set_option('display.float_format', '{:.0f}'.format)

# %%
print(df.describe())
# Out:
#        total_bill  tip  size  price_per_person        CC Number
# count         244  244   244               244              244
# mean           20    3     3                 8 2563495461217592
# std             9    1     1                 3 2369339716610890
# min             3    1     1                 3      60406789937
# 25%            13    2     2                 6   30407325000000
# 50%            18    3     2                 7 3525320000000000
# 75%            24    4     3                 9 4553675000000000
# max            51   10     6                20 6596450000000000

# %%
pd.set_option('display.float_format', lambda x: '%.0f' % x)

# %%
print(df.describe())
# Out:
#        total_bill  tip  size  price_per_person        CC Number
# count         244  244   244               244              244
# mean           20    3     3                 8 2563495461217592
# std             9    1     1                 3 2369339716610890
# min             3    1     1                 3      60406789937
# 25%            13    2     2                 6   30407325000000
# 50%            18    3     2                 7 3525320000000000
# 75%            24    4     3                 9 4553675000000000
# max            51   10     6                20 6596450000000000

# %%
print(df['total_bill'])
# Out:
# 0     17
# 1     10
# 2     21
# 3     24
# 4     25
#       ..
# 239   29
# 240   27
# 241   23
# 242   18
# 243   19
# Name: total_bill, Length: 244, dtype: float64

# %%
print(df.total_bill)
# Out:
# 0     17
# 1     10
# 2     21
# 3     24
# 4     25
#       ..
# 239   29
# 240   27
# 241   23
# 242   18
# 243   19
# Name: total_bill, Length: 244, dtype: float64

# %%
print(df[['total_bill', 'tip']])
# Out:
#      total_bill  tip
# 0            17    1
# 1            10    2
# 2            21    4
# 3            24    3
# 4            25    4
# ..          ...  ...
# 239          29    6
# 240          27    2
# 241          23    2
# 242          18    2
# 243          19    3
#
# [244 rows x 2 columns]

# %%
df['tip_percentage'] = (df['tip'] / df['total_bill']) * 100

# %%
df
# Out:
#      total_bill  tip  gender smoker   day    time  size  price_per_person  \
# 0            17    1  Female     No   Sun  Dinner     2                 8
# 1            10    2    Male     No   Sun  Dinner     3                 3
# 2            21    4    Male     No   Sun  Dinner     3                 7
# 3            24    3    Male     No   Sun  Dinner     2                12
# 4            25    4  Female     No   Sun  Dinner     4                 6
# ..          ...  ...     ...    ...   ...     ...   ...               ...
# 239          29    6    Male     No   Sat  Dinner     3                10
# 240          27    2  Female    Yes   Sat  Dinner     2                14
# 241          23    2    Male    Yes   Sat  Dinner     2                11
# 242          18    2    Male     No   Sat  Dinner     2                 9
# 243          19    3  Female     No  Thur  Dinner     2                 9
#
#              Payer Name        CC Number Payment ID  tip_percentage
# ...

# %%
df['price_per_person'] = df['total_bill'] / df['size']

# %%
df
# Out:
#      total_bill  tip  gender smoker   day    time  size  price_per_person  \
# 0            17    1  Female     No   Sun  Dinner     2                 8
# 1            10    2    Male     No   Sun  Dinner     3                 3
# 2            21    4    Male     No   Sun  Dinner     3                 7
# 3            24    3    Male     No   Sun  Dinner     2                12
# 4            25    4  Female     No   Sun  Dinner     4                 6
# ..          ...  ...     ...    ...   ...     ...   ...               ...
# 239          29    6    Male     No   Sat  Dinner     3                10
# 240          27    2  Female    Yes   Sat  Dinner     2                14
# 241          23    2    Male    Yes   Sat  Dinner     2                11
# 242          18    2    Male     No   Sat  Dinner     2                 9
# 243          19    3  Female     No  Thur  Dinner     2                 9
#
#              Payer Name        CC Number Payment ID  tip_percentage
# ...

# %%
df['price_per_person'] = np.round(df['total_bill'] / df['size'])

# %%
df
# Out:
#      total_bill  tip  gender smoker   day    time  size  price_per_person  \
# 0            17    1  Female     No   Sun  Dinner     2                 8
# 1            10    2    Male     No   Sun  Dinner     3                 3
# 2            21    4    Male     No   Sun  Dinner     3                 7
# 3            24    3    Male     No   Sun  Dinner     2                12
# 4            25    4  Female     No   Sun  Dinner     4                 6
# ..          ...  ...     ...    ...   ...     ...   ...               ...
# 239          29    6    Male     No   Sat  Dinner     3                10
# 240          27    2  Female    Yes   Sat  Dinner     2                14
# 241          23    2    Male    Yes   Sat  Dinner     2                11
# 242          18    2    Male     No   Sat  Dinner     2                 9
# 243          19    3  Female     No  Thur  Dinner     2                 9
#
#              Payer Name        CC Number Payment ID  tip_percentage
# ...

# %%
df = df.drop('tip_percentage', axis=1)

# %%
df
# Out:
#      total_bill  tip  gender smoker   day    time  size  price_per_person  \
# 0            17    1  Female     No   Sun  Dinner     2                 8
# 1            10    2    Male     No   Sun  Dinner     3                 3
# 2            21    4    Male     No   Sun  Dinner     3                 7
# 3            24    3    Male     No   Sun  Dinner     2                12
# 4            25    4  Female     No   Sun  Dinner     4                 6
# ..          ...  ...     ...    ...   ...     ...   ...               ...
# 239          29    6    Male     No   Sat  Dinner     3                10
# 240          27    2  Female    Yes   Sat  Dinner     2                14
# 241          23    2    Male    Yes   Sat  Dinner     2                11
# 242          18    2    Male     No   Sat  Dinner     2                 9
# 243          19    3  Female     No  Thur  Dinner     2                 9
#
#              Payer Name        CC Number Payment ID
# ...

# %%
df = df.set_index('Payment ID')

# %%
df
# Out:
#             total_bill  tip  gender smoker   day    time  size  \
# Payment ID
# Sun2959             17    1  Female     No   Sun  Dinner     2
# Sun4608             10    2    Male     No   Sun  Dinner     3
# Sun4458             21    4    Male     No   Sun  Dinner     3
# Sun5260             24    3    Male     No   Sun  Dinner     2
# Sun2251             25    4  Female     No   Sun  Dinner     4
# ...                ...  ...     ...    ...   ...     ...   ...
# Sat2657             29    6    Male     No   Sat  Dinner     3
# Sat1766             27    2  Female    Yes   Sat  Dinner     2
# Sat3880             23    2    Male    Yes   Sat  Dinner     2
# Sat17               18    2    Male     No   Sat  Dinner     2
# Thur672             19    3  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name        CC Number
# Payment ID
# Sun2959                    8  Christy Cunningham 3560330000000000
# ...

# %%
df = df.reset_index()

# %%
df
# Out:
#     Payment ID  total_bill  tip  gender smoker   day    time  size  \
# 0      Sun2959          17    1  Female     No   Sun  Dinner     2
# 1      Sun4608          10    2    Male     No   Sun  Dinner     3
# 2      Sun4458          21    4    Male     No   Sun  Dinner     3
# 3      Sun5260          24    3    Male     No   Sun  Dinner     2
# 4      Sun2251          25    4  Female     No   Sun  Dinner     4
# ..         ...         ...  ...     ...    ...   ...     ...   ...
# 239    Sat2657          29    6    Male     No   Sat  Dinner     3
# 240    Sat1766          27    2  Female    Yes   Sat  Dinner     2
# 241    Sat3880          23    2    Male    Yes   Sat  Dinner     2
# 242      Sat17          18    2    Male     No   Sat  Dinner     2
# 243    Thur672          19    3  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name        CC Number
# 0                   8  Christy Cunningham 3560330000000000
# ...

# %%
print(df['total_bill'] > 30)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: total_bill, Length: 244, dtype: bool

# %%
print(df[df['total_bill'] > 30])
# Out:
#     Payment ID  total_bill  tip  gender smoker   day    time  size  \
# 11     Sun6686          35    5  Female     No   Sun  Dinner     4
# 23      Sat239          39    8    Male     No   Sat  Dinner     4
# 39     Sat6373          31    5    Male     No   Sat  Dinner     3
# 44     Sun2274          30    6    Male     No   Sun  Dinner     4
# 47     Sun9677          32    6    Male     No   Sun  Dinner     4
# 52     Sun6165          35    5  Female     No   Sun  Dinner     4
# 56     Sat8903          38    3    Male    Yes   Sat  Dinner     4
# 59     Sat8139          48    7    Male     No   Sat  Dinner     4
# 83    Thur8801          33    5    Male    Yes  Thur   Lunch     2
# 85    Thur7972          35    5  Female     No  Thur   Lunch     4
# 95     Fri9628          40    5    Male    Yes   Fri  Dinner     4
# 102    Sat6240          44    2  Female    Yes   Sat  Dinner     3
# 112     Sun591          38    4    Male     No   Sun  Dinner     3
# ...

# %%
filter_df = df[(df['total_bill'] > 30) & (df['gender'] == "Male")]
filter_df
# Out:
#     Payment ID  total_bill  tip gender smoker   day    time  size  \
# 23      Sat239          39    8   Male     No   Sat  Dinner     4
# 39     Sat6373          31    5   Male     No   Sat  Dinner     3
# 44     Sun2274          30    6   Male     No   Sun  Dinner     4
# 47     Sun9677          32    6   Male     No   Sun  Dinner     4
# 56     Sat8903          38    3   Male    Yes   Sat  Dinner     4
# 59     Sat8139          48    7   Male     No   Sat  Dinner     4
# 83    Thur8801          33    5   Male    Yes  Thur   Lunch     2
# 95     Fri9628          40    5   Male    Yes   Fri  Dinner     4
# 112     Sun591          38    4   Male     No   Sun  Dinner     3
# 141   Thur1025          34    7   Male     No  Thur   Lunch     6
# 142   Thur3621          41    5   Male     No  Thur   Lunch     5
# 156    Sun7518          48    5   Male     No   Sun  Dinner     6
# 167    Sun3719          32    4   Male     No   Sun  Dinner     4
# ...

# %%
print(df[(df['total_bill'] > 30) | (df['size'] >= 5)])
# Out:
#     Payment ID  total_bill  tip  gender smoker   day    time  size  \
# 11     Sun6686          35    5  Female     No   Sun  Dinner     4
# 23      Sat239          39    8    Male     No   Sat  Dinner     4
# 39     Sat6373          31    5    Male     No   Sat  Dinner     3
# 44     Sun2274          30    6    Male     No   Sun  Dinner     4
# 47     Sun9677          32    6    Male     No   Sun  Dinner     4
# 52     Sun6165          35    5  Female     No   Sun  Dinner     4
# 56     Sat8903          38    3    Male    Yes   Sat  Dinner     4
# 59     Sat8139          48    7    Male     No   Sat  Dinner     4
# 83    Thur8801          33    5    Male    Yes  Thur   Lunch     2
# 85    Thur7972          35    5  Female     No  Thur   Lunch     4
# 95     Fri9628          40    5    Male    Yes   Fri  Dinner     4
# 102    Sat6240          44    2  Female    Yes   Sat  Dinner     3
# 112     Sun591          38    4    Male     No   Sun  Dinner     3
# ...

# %%
options = ['Sat', 'Sun']

# %%
print(df[df['day'].isin(options)])
# Out:
#     Payment ID  total_bill  tip  gender smoker  day    time  size  \
# 0      Sun2959          17    1  Female     No  Sun  Dinner     2
# 1      Sun4608          10    2    Male     No  Sun  Dinner     3
# 2      Sun4458          21    4    Male     No  Sun  Dinner     3
# 3      Sun5260          24    3    Male     No  Sun  Dinner     2
# 4      Sun2251          25    4  Female     No  Sun  Dinner     4
# ..         ...         ...  ...     ...    ...  ...     ...   ...
# 238    Sat9777          36    5  Female     No  Sat  Dinner     3
# 239    Sat2657          29    6    Male     No  Sat  Dinner     3
# 240    Sat1766          27    2  Female    Yes  Sat  Dinner     2
# 241    Sat3880          23    2    Male    Yes  Sat  Dinner     2
# 242      Sat17          18    2    Male     No  Sat  Dinner     2
#
#      price_per_person          Payer Name        CC Number
# 0                   8  Christy Cunningham 3560330000000000
# ...

# %%
filterd1 = df[(df['gender'] == "Female") & (df['tip'] >= 4)]
filtered2 = df.query("gender == 'Female' and tip >= 4")
filtered3 = df.loc[(df['gender'] == "Female") & (df['tip'] >= 4)]
filtered4 = df.where((df['gender'] == "Female") & (df['tip'] >= 4)).dropna()

# %%
print(filterd1)
# Out:
#     Payment ID  total_bill  tip  gender smoker   day    time  size  \
# 11     Sun6686          35    5  Female     No   Sun  Dinner     4
# 52     Sun6165          35    5  Female     No   Sun  Dinner     4
# 73     Sat6065          25    5  Female    Yes   Sat  Dinner     2
# 85    Thur7972          35    5  Female     No  Thur   Lunch     4
# 93     Fri6963          16    4  Female    Yes   Fri  Dinner     2
# 104    Sat3194          21    4  Female     No   Sat  Dinner     2
# 109    Sat2614          14    4  Female    Yes   Sat  Dinner     2
# 114    Sun6492          26    4  Female     No   Sun  Dinner     3
# 125   Thur3948          30    4  Female     No  Thur   Lunch     6
# 143   Thur6179          27    5  Female     No  Thur   Lunch     6
# 155    Sun9176          30    5  Female     No   Sun  Dinner     5
# 178    Sun4598          10    4  Female    Yes   Sun  Dinner     2
# 191    Thur967          20    4  Female    Yes  Thur   Lunch     2
# ...

# %%
print(filtered2)
# Out:
#     Payment ID  total_bill  tip  gender smoker   day    time  size  \
# 11     Sun6686          35    5  Female     No   Sun  Dinner     4
# 52     Sun6165          35    5  Female     No   Sun  Dinner     4
# 73     Sat6065          25    5  Female    Yes   Sat  Dinner     2
# 85    Thur7972          35    5  Female     No  Thur   Lunch     4
# 93     Fri6963          16    4  Female    Yes   Fri  Dinner     2
# 104    Sat3194          21    4  Female     No   Sat  Dinner     2
# 109    Sat2614          14    4  Female    Yes   Sat  Dinner     2
# 114    Sun6492          26    4  Female     No   Sun  Dinner     3
# 125   Thur3948          30    4  Female     No  Thur   Lunch     6
# 143   Thur6179          27    5  Female     No  Thur   Lunch     6
# 155    Sun9176          30    5  Female     No   Sun  Dinner     5
# 178    Sun4598          10    4  Female    Yes   Sun  Dinner     2
# 191    Thur967          20    4  Female    Yes  Thur   Lunch     2
# ...

# %%
print(filtered3)
# Out:
#     Payment ID  total_bill  tip  gender smoker   day    time  size  \
# 11     Sun6686          35    5  Female     No   Sun  Dinner     4
# 52     Sun6165          35    5  Female     No   Sun  Dinner     4
# 73     Sat6065          25    5  Female    Yes   Sat  Dinner     2
# 85    Thur7972          35    5  Female     No  Thur   Lunch     4
# 93     Fri6963          16    4  Female    Yes   Fri  Dinner     2
# 104    Sat3194          21    4  Female     No   Sat  Dinner     2
# 109    Sat2614          14    4  Female    Yes   Sat  Dinner     2
# 114    Sun6492          26    4  Female     No   Sun  Dinner     3
# 125   Thur3948          30    4  Female     No  Thur   Lunch     6
# 143   Thur6179          27    5  Female     No  Thur   Lunch     6
# 155    Sun9176          30    5  Female     No   Sun  Dinner     5
# 178    Sun4598          10    4  Female    Yes   Sun  Dinner     2
# 191    Thur967          20    4  Female    Yes  Thur   Lunch     2
# ...

# %%
print(filtered4)
# Out:
#     Payment ID  total_bill  tip  gender smoker   day    time  size  \
# 11     Sun6686          35    5  Female     No   Sun  Dinner     4
# 52     Sun6165          35    5  Female     No   Sun  Dinner     4
# 73     Sat6065          25    5  Female    Yes   Sat  Dinner     2
# 85    Thur7972          35    5  Female     No  Thur   Lunch     4
# 93     Fri6963          16    4  Female    Yes   Fri  Dinner     2
# 104    Sat3194          21    4  Female     No   Sat  Dinner     2
# 109    Sat2614          14    4  Female    Yes   Sat  Dinner     2
# 114    Sun6492          26    4  Female     No   Sun  Dinner     3
# 125   Thur3948          30    4  Female     No  Thur   Lunch     6
# 143   Thur6179          27    5  Female     No  Thur   Lunch     6
# 155    Sun9176          30    5  Female     No   Sun  Dinner     5
# 178    Sun4598          10    4  Female    Yes   Sun  Dinner     2
# 191    Thur967          20    4  Female    Yes  Thur   Lunch     2
# ...

# %%
gender_counts = df['gender'].value_counts()
gender_counts
# Out:
# gender
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
sorted_by_bill = df.sort_values(by='total_bill')
sorted_by_bill
# Out:
#     Payment ID  total_bill  tip  gender smoker   day    time  size  \
# 67     Sat3455           3    1  Female    Yes   Sat  Dinner     1
# 92     Fri3780           6    1  Female    Yes   Fri  Dinner     2
# 111    Sat4801           7    1  Female     No   Sat  Dinner     1
# 172    Sun9209           7    5    Male    Yes   Sun  Dinner     2
# 149   Thur6321           8    2    Male     No  Thur   Lunch     2
# ..         ...         ...  ...     ...    ...   ...     ...   ...
# 182    Sun2337          45    4    Male    Yes   Sun  Dinner     3
# 156    Sun7518          48    5    Male     No   Sun  Dinner     6
# 59     Sat8139          48    7    Male     No   Sat  Dinner     4
# 212    Sat4590          48    9    Male     No   Sat  Dinner     4
# 170    Sat1954          51   10    Male    Yes   Sat  Dinner     3
#
#      price_per_person       Payer Name        CC Number
# 67                  3    Tiffany Brock 4359490000000000
# ...

# %%
sorted_by_tip_desc = df.sort_values(by='tip', ascending=False)
sorted_by_tip_desc
# Out:
#     Payment ID  total_bill  tip  gender smoker   day    time  size  \
# 170    Sat1954          51   10    Male    Yes   Sat  Dinner     3
# 212    Sat4590          48    9    Male     No   Sat  Dinner     4
# 23      Sat239          39    8    Male     No   Sat  Dinner     4
# 59     Sat8139          48    7    Male     No   Sat  Dinner     4
# 141   Thur1025          34    7    Male     No  Thur   Lunch     6
# ..         ...         ...  ...     ...    ...   ...     ...   ...
# 0      Sun2959          17    1  Female     No   Sun  Dinner     2
# 111    Sat4801           7    1  Female     No   Sat  Dinner     1
# 92     Fri3780           6    1  Female    Yes   Fri  Dinner     2
# 67     Sat3455           3    1  Female    Yes   Sat  Dinner     1
# 236    Sat5032          13    1    Male    Yes   Sat  Dinner     2
#
#      price_per_person          Payer Name        CC Number
# 170                17       Gregory Clark 5473850000000000
# ...

# %%
sorted_multiple = df.sort_values(by=['day', 'total_bill'], ascending=[True, False])
sorted_multiple
# Out:
#     Payment ID  total_bill  tip  gender smoker   day    time  size  \
# 95     Fri9628          40    5    Male    Yes   Fri  Dinner     4
# 90     Fri4175          29    3    Male    Yes   Fri  Dinner     2
# 96     Fri3159          27    4    Male    Yes   Fri  Dinner     2
# 94     Fri2318          23    3  Female     No   Fri  Dinner     2
# 91     Fri5700          22    4    Male     No   Fri  Dinner     2
# ..         ...         ...  ...     ...    ...   ...     ...   ...
# 126   Thur6719           9    1    Male     No  Thur   Lunch     2
# 135   Thur6600           9    1  Female     No  Thur   Lunch     2
# 145   Thur9331           8    2  Female     No  Thur   Lunch     2
# 195    Thur697           8    1    Male     No  Thur   Lunch     2
# 149   Thur6321           8    2    Male     No  Thur   Lunch     2
#
#      price_per_person      Payer Name        CC Number
# 95                 10   Aaron Bentley  180027000000000
# ...

# %%
sorted_multiple.day.drop_duplicates()
# Out:
# 95      Fri
# 170     Sat
# 156     Sun
# 197    Thur
# Name: day, dtype: object

# %%
pd.DataFrame(['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'], columns=['Day']).sort_values(by='Day', ascending=True)
# Out:
#    Day
# 4  Fri
# 0  Mon
# 5  Sat
# 6  Sun
# 3  Thu
# 1  Tue
# 2  Wed

# %%
pd.DataFrame(['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'], columns=['Day']).sort_values(by='Day', ascending=False)
# Out:
#    Day
# 2  Wed
# 1  Tue
# 3  Thu
# 6  Sun
# 5  Sat
# 0  Mon
# 4  Fri
